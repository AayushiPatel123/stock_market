# %%
import pandas as pd

dff = pd.read_csv("Fortune_1000.csv")

# %%
{dff['company'].tolist()[i]: dff['company'].tolist()[i + 1] for i in range(0, len(dff['company'].tolist()), 2)}
# Out:
# {'Walmart': 'Amazon',
#  'Apple': 'CVS Health',
#  'UnitedHealth Group': 'Exxon Mobil',
#  'Berkshire Hathaway': 'Alphabet',
#  'McKesson': 'AmerisourceBergen',
#  'Costco Wholesale': 'Cigna',
#  'AT&T': 'Microsoft',
#  'Cardinal Health': 'Chevron',
#  'Home Depot': 'Walgreens Boots Alliance',
#  'Marathon Petroleum': 'Elevance Health',
#  'Kroger': 'Ford Motor',
#  'Verizon Communications': 'JPMorgan Chase',
#  'General Motors': 'Centene',
#  'Meta Platforms': 'Comcast',
#  'Phillips 66': 'Valero Energy',
#  'Dell Technologies': 'Target',
#  'Fannie Mae': 'United Parcel Service',
#  "Lowe's": 'Bank of America',
#  'Johnson & Johnson': 'Archer Daniels Midland',
#  'FedEx': 'Humana',
#  'Wells Fargo': 'State Farm Insurance',
#  'Pfizer': 'Citigroup',
#  'PepsiCo': 'Intel',
#  'Procter & Gamble': 'General Electric',
#  'IBM': 'MetLife',
#  'Prudential Financial': 'Albertsons',
#  'Walt Disney': 'Energy Transfer',
#  'Lockheed Martin': 'Freddie Mac',
# ...
